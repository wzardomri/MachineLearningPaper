# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import pickle
from matplotlib import pyplot
from keras.optimizers import SGD
np.set_printoptions(threshold=np.sys.maxsize)

# %%
#define the data
FullData = pd.read_csv("Counter_Correction_DataNormalized.csv")

x, y = FullData.values[:, 1:-1], FullData.values[:, -1]
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
n_features = x_train.shape[1]

# %%
y_traininput = tf.keras.utils.to_categorical(y_train)
y_testinput = tf.keras.utils.to_categorical(y_test)  
x_train = np.asarray(x_train).astype('float32')
x_test = np.asarray(x_test).astype('float32')
y_traininput = np.asarray(y_traininput).astype('float32')
y_testinput = np.asarray(y_testinput).astype('float32')

# %%
# define the model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(100, input_shape=(n_features,), activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(10, activation= "relu"))
model.add(tf.keras.layers.Dense(10, activation= "relu"))
model.add(tf.keras.layers.Dense(10, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(32, activation='softmax'))

opt = SGD(lr=0.01)

model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])

# %%
history = model.fit(x_train, y_traininput, epochs=1000)

# %%
train_acc = 0
while(train_acc < 0.70):
    import tensorflow as tf
    import pandas as pd
    import numpy as np
    from sklearn.model_selection import train_test_split
    import pickle
    from matplotlib import pyplot
    from keras.optimizers import SGD
    np.set_printoptions(threshold=np.sys.maxsize)
    
    #define the data
    FullData = pd.read_csv("Counter_Correction_DataNonNormalized.csv")

    x, y = FullData.values[:, 1:-1], FullData.values[:, -1]
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.1)
    print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
    n_features = x_train.shape[1]
    
    y_traininput = tf.keras.utils.to_categorical(y_train)
    y_testinput = tf.keras.utils.to_categorical(y_test)
    x_testoutputcheck = x_test
    x_train = np.asarray(x_train).astype('float32')
    x_test = np.asarray(x_test).astype('float32')
    y_traininput = np.asarray(y_traininput).astype('float32')
    y_testinput = np.asarray(y_testinput).astype('float32')
    y_testoutputcheck = y_test
    y_test = np.asarray(y_test).astype('float32')
    train_acc = 0
    while(train_acc < 0.4):
        model = tf.keras.Sequential()
        model.add(tf.keras.layers.Dense(100, input_shape=(n_features,), activation= "relu"))
        model.add(tf.keras.layers.Dense(80, activation= "relu"))
        model.add(tf.keras.layers.Dense(80, activation= "relu"))
        model.add(tf.keras.layers.Dense(80, activation= "relu"))
        model.add(tf.keras.layers.Dense(80, activation= "relu"))
        model.add(tf.keras.layers.Dense(80, activation= "relu"))
        model.add(tf.keras.layers.Dense(30, activation= "relu"))
        model.add(tf.keras.layers.Dense(30, activation= "relu"))
        model.add(tf.keras.layers.Dense(30, activation= "relu"))
        model.add(tf.keras.layers.Dense(30, activation= "relu"))
        model.add(tf.keras.layers.Dense(10, activation= "relu"))
        model.add(tf.keras.layers.Dense(10, activation= "relu"))
        model.add(tf.keras.layers.Dense(10, activation= "relu"))
        model.add(tf.keras.layers.Dense(5, activation= "relu"))
        model.add(tf.keras.layers.Dense(5, activation= "relu"))
        model.add(tf.keras.layers.Dense(5, activation= "relu"))
        model.add(tf.keras.layers.Dense(5, activation= "relu"))
        model.add(tf.keras.layers.Dense(5, activation= "relu"))
        model.add(tf.keras.layers.Dense(32, activation='softmax'))
        opt = SGD(lr=0.01)
        model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])
        history = model.fit(x_train, y_traininput, epochs=15, verbose = 1)
        _, train_acc = model.evaluate(x_train, y_traininput, verbose=1)
    
    history = model.fit(x_train, y_traininput, epochs=150, verbose = 1)
    
    _, train_acc = model.evaluate(x_train, y_traininput, verbose=1)
    _, test_acc = model.evaluate(x_test, y_testinput, verbose=0)
    
    print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
    # plot loss during training
    pyplot.subplot(211)
    pyplot.title('Loss')
    pyplot.plot(history.history['loss'], label='train')
    pyplot.legend()
    # plot accuracy during training
    pyplot.subplot(212)
    pyplot.title('Accuracy')
    pyplot.plot(history.history['accuracy'], label='train')
    pyplot.legend()
    pyplot.show()

    predictions = model.predict(x_testoutputcheck)
    y_pred_classes = np.argmax(predictions, axis=1)
    
    # compute class-wise accuracy and confusion matrix
    class_correct = [0] * 32
    class_total = [0] * 32
    class_true = [0] * 32
    class_false = [[0] * 32 for _ in range(32)]

    for i in range(len(y_testoutputcheck)):
        true_class = y_testoutputcheck[i]
        pred_class = y_pred_classes[i]

        if true_class == pred_class:
            class_correct[true_class] += 1
            class_true[true_class] += 1
        else:
            class_false[true_class][pred_class] += 1

        class_total[true_class] += 1

    class_accuracy = [class_correct[i] / (class_total[i] + 1) for i in range(32)]

    # print class-wise results
    if(train_acc > 0.5):
        for class_id in range(32):
            print(f"Class {class_id}:")
            print(f"  Total: {class_total[class_id]}")
            print(f"  Correct: {class_correct[class_id]}")
            print(f"  True {class_id}: {class_true[class_id]}")
            print(f"  False: {class_false[class_id]}")
            print(f"  Accuracy: {class_accuracy[class_id]}")
        

with open('Countercorrectionmodel.pkl', 'wb') as f:
    pickle.dump({'weights': model.get_weights(), 'history': history.history}, f)

history = model.fit(x_train, y_traininput, epochs=1000, verbose=1)
with open('Countercorrectionmodelper.pkl', 'wb') as f:
    pickle.dump({'weights': model.get_weights(), 'history': history.history}, f)
# Out:
# (90000, 3) (10000, 3) (90000,) (10000,)
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4655 - accuracy: 0.0333
# Epoch 2/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4572 - accuracy: 0.0305
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.2499 - accuracy: 0.0638
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.8607 - accuracy: 0.1050
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.5094 - accuracy: 0.1503
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.3757 - accuracy: 0.1946
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.2879 - accuracy: 0.2139
# Epoch 8/15
# 2813/2813 [==============================] - 117s 41ms/step - loss: 2.1608 - accuracy: 0.2686
# Epoch 9/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.1794 - accuracy: 0.2959
# Epoch 10/15
# 2813/2813 [==============================] - 7s 2ms/step - loss: 2.3452 - accuracy: 0.2466
# Epoch 11/15
# 2813/2813 [==============================] - 13s 4ms/step - loss: 2.1665 - accuracy: 0.2684
# Epoch 12/15
# 2813/2813 [==============================] - 12s 4ms/step - loss: 2.0591 - accuracy: 0.3047
# Epoch 13/15
# 2813/2813 [==============================] - 12s 4ms/step - loss: 2.0249 - accuracy: 0.3170
# Epoch 14/15
# 2813/2813 [==============================] - 12s 4ms/step - loss: 2.0022 - accuracy: 0.3344
# Epoch 15/15
# 2813/2813 [==============================] - 12s 4ms/step - loss: 3.5453 - accuracy: 0.2110
# 2813/2813 [==============================] - 9s 3ms/step - loss: 3.1879 - accuracy: 0.2509
# Epoch 1/15
# 2813/2813 [==============================] - 14s 4ms/step - loss: 3.4644 - accuracy: 0.0410
# Epoch 2/15
# 2813/2813 [==============================] - 13s 5ms/step - loss: 3.3294 - accuracy: 0.0628
# Epoch 3/15
# 2813/2813 [==============================] - 13s 5ms/step - loss: 2.8782 - accuracy: 0.0889
# Epoch 4/15
# 2813/2813 [==============================] - 13s 5ms/step - loss: 2.5115 - accuracy: 0.1393
# Epoch 5/15
# 2813/2813 [==============================] - 13s 4ms/step - loss: 2.2976 - accuracy: 0.1751
# Epoch 6/15
# 2813/2813 [==============================] - 13s 5ms/step - loss: 2.1727 - accuracy: 0.2033
# Epoch 7/15
# 2813/2813 [==============================] - 14s 5ms/step - loss: 2.0715 - accuracy: 0.2402
# Epoch 8/15
# 2813/2813 [==============================] - 13s 4ms/step - loss: 1.9909 - accuracy: 0.2638
# Epoch 9/15
# 2813/2813 [==============================] - 27s 10ms/step - loss: 1.9006 - accuracy: 0.2910
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.9966 - accuracy: 0.3073
# Epoch 11/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.2109 - accuracy: 0.0998
# Epoch 12/15
# 2813/2813 [==============================] - 16s 6ms/step - loss: 3.1504 - accuracy: 0.1140
# Epoch 13/15
# 2813/2813 [==============================] - 12s 4ms/step - loss: 3.1308 - accuracy: 0.1143
# Epoch 14/15
# 2813/2813 [==============================] - 23s 8ms/step - loss: 3.1266 - accuracy: 0.1144
# Epoch 15/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.1235 - accuracy: 0.1143
# 2813/2813 [==============================] - 3s 858us/step - loss: 3.1217 - accuracy: 0.1141
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0313
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0298
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 4/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0329
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4657 - accuracy: 0.0312
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0318
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0299
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0320
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0312
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0321
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# 2813/2813 [==============================] - 2s 798us/step - loss: 3.4657 - accuracy: 0.0315
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0317
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0317
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0322
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0315
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0319
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0294
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0300
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0312
# 2813/2813 [==============================] - 2s 793us/step - loss: 3.4657 - accuracy: 0.0316
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0289
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0319
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0314
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 5/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 6/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0319
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0315
# Epoch 9/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0318
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0322
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0318
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0324
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0315
# 2813/2813 [==============================] - 3s 859us/step - loss: 3.4657 - accuracy: 0.0315
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0318
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4657 - accuracy: 0.0318
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4654 - accuracy: 0.0302
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4650 - accuracy: 0.0334
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4630 - accuracy: 0.0394
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.3867 - accuracy: 0.0638
# Epoch 7/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.0035 - accuracy: 0.0800
# Epoch 8/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.5455 - accuracy: 0.1504
# Epoch 9/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.2933 - accuracy: 0.2048
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.0718 - accuracy: 0.2549
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.8848 - accuracy: 0.3157
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.7408 - accuracy: 0.3568
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.6667 - accuracy: 0.3950
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.6305 - accuracy: 0.4120
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.5127 - accuracy: 0.4428
# 2813/2813 [==============================] - 2s 809us/step - loss: 1.2320 - accuracy: 0.4795
# Epoch 1/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.4734 - accuracy: 0.4624
# Epoch 2/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3943 - accuracy: 0.4878
# Epoch 3/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3425 - accuracy: 0.5047
# Epoch 4/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3033 - accuracy: 0.5191
# Epoch 5/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.2787 - accuracy: 0.5308
# Epoch 6/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.7723 - accuracy: 0.4157
# Epoch 7/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.6430 - accuracy: 0.1233
# Epoch 8/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.3110 - accuracy: 0.1953
# Epoch 9/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.5701 - accuracy: 0.0492
# Epoch 10/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.5501 - accuracy: 0.0318
# Epoch 11/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4905 - accuracy: 0.0310
# Epoch 12/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4719 - accuracy: 0.0312
# Epoch 13/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4671 - accuracy: 0.0310
# Epoch 14/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4661 - accuracy: 0.0303
# Epoch 15/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0311
# Epoch 16/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0314
# Epoch 17/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 18/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 19/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0297
# Epoch 20/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 21/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0303
# Epoch 22/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 23/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0295
# Epoch 24/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0310
# Epoch 25/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 26/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0302
# Epoch 27/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0303
# Epoch 28/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0309
# Epoch 29/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 30/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 31/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0302
# Epoch 32/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0301
# Epoch 33/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 34/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0299
# Epoch 35/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 36/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0305
# Epoch 37/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 38/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0301
# Epoch 39/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0301
# Epoch 40/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 41/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 42/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 43/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 44/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 45/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 46/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 47/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 48/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0307
# Epoch 49/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0297
# Epoch 50/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0302
# Epoch 51/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0308
# Epoch 52/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 53/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 54/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0302
# Epoch 55/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0299
# Epoch 56/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0303
# Epoch 57/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 58/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0303
# Epoch 59/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 60/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0298
# Epoch 61/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0308
# Epoch 62/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0303
# Epoch 63/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 64/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0311
# Epoch 65/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 66/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0311
# Epoch 67/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0294
# Epoch 68/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0302
# Epoch 69/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 70/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 71/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 72/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0313
# Epoch 73/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 74/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0293
# Epoch 75/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 76/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 77/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 78/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 79/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 80/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 81/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0298
# Epoch 82/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 83/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0307
# Epoch 84/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0307
# Epoch 85/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 86/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0300
# Epoch 87/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0301
# Epoch 88/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0305
# Epoch 89/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 90/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0312
# Epoch 91/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0298
# Epoch 92/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 93/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 94/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 95/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 96/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0312
# Epoch 97/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 98/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0295
# Epoch 99/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0298
# Epoch 100/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 101/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0295
# Epoch 102/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 103/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 104/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0300
# Epoch 105/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 106/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0297
# Epoch 107/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0300
# Epoch 108/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0298
# Epoch 109/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0307
# Epoch 110/150
# 2813/2813 [==============================] - 66s 23ms/step - loss: 3.4659 - accuracy: 0.0313
# Epoch 111/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 112/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0301
# Epoch 113/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0308
# Epoch 114/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0294
# Epoch 115/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 116/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0308
# Epoch 117/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0310
# Epoch 118/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0311
# Epoch 119/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0300
# Epoch 120/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 121/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0313
# Epoch 122/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 123/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4659 - accuracy: 0.0309
# Epoch 124/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0308
# Epoch 125/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 126/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0315
# Epoch 127/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 128/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 129/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0312
# Epoch 130/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0312
# Epoch 131/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0294
# Epoch 132/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 133/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0294
# Epoch 134/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0306
# Epoch 135/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 136/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 137/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0311
# Epoch 138/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 139/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 140/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0297
# Epoch 141/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0305
# Epoch 142/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 143/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0308
# Epoch 144/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 145/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 146/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0305
# Epoch 147/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0301
# Epoch 148/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0300
# Epoch 149/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0292
# Epoch 150/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0297
# 2813/2813 [==============================] - 2s 736us/step - loss: 3.4657 - accuracy: 0.0315
# Train: 0.032, Test: 0.029
# (90000, 3) (10000, 3) (90000,) (10000,)
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0321
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0298
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0299
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0320
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0321
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0313
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0305
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0327
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# 2813/2813 [==============================] - 2s 796us/step - loss: 3.4657 - accuracy: 0.0315
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0299
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0325
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4656 - accuracy: 0.0307
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4654 - accuracy: 0.0348
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4648 - accuracy: 0.0340
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4608 - accuracy: 0.0465
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4040 - accuracy: 0.0619
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.1259 - accuracy: 0.0573
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.8153 - accuracy: 0.0990
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.6339 - accuracy: 0.1320
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.5344 - accuracy: 0.1416
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.4383 - accuracy: 0.1483
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.3537 - accuracy: 0.1621
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.2679 - accuracy: 0.1658
# 2813/2813 [==============================] - 2s 792us/step - loss: 2.2399 - accuracy: 0.0417
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4656 - accuracy: 0.0286
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4518 - accuracy: 0.0724
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.8834 - accuracy: 0.0665
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.5025 - accuracy: 0.1307
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.2957 - accuracy: 0.1817
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.1414 - accuracy: 0.2086
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.0505 - accuracy: 0.2589
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.9677 - accuracy: 0.2658
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.9171 - accuracy: 0.2853
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.8700 - accuracy: 0.2875
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.8398 - accuracy: 0.3050
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.7758 - accuracy: 0.3266
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.7030 - accuracy: 0.3665
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.5728 - accuracy: 0.4174
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.5620 - accuracy: 0.4249
# 2813/2813 [==============================] - 2s 775us/step - loss: 1.1258 - accuracy: 0.5821
# Epoch 1/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.5947 - accuracy: 0.4098
# Epoch 2/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.4071 - accuracy: 0.2694
# Epoch 3/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.0242 - accuracy: 0.1456
# Epoch 4/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.0048 - accuracy: 0.1456
# Epoch 5/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.9962 - accuracy: 0.1447
# Epoch 6/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9914 - accuracy: 0.1449
# Epoch 7/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9883 - accuracy: 0.1453
# Epoch 8/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9861 - accuracy: 0.1454
# Epoch 9/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9844 - accuracy: 0.1451
# Epoch 10/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9831 - accuracy: 0.1450
# Epoch 11/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9820 - accuracy: 0.1450
# Epoch 12/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9812 - accuracy: 0.1445
# Epoch 13/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9804 - accuracy: 0.1449
# Epoch 14/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9798 - accuracy: 0.1452
# Epoch 15/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.9793 - accuracy: 0.1458
# Epoch 16/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9789 - accuracy: 0.1451
# Epoch 17/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9785 - accuracy: 0.1452
# Epoch 18/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9781 - accuracy: 0.1453
# Epoch 19/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9778 - accuracy: 0.1452
# Epoch 20/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9775 - accuracy: 0.1452
# Epoch 21/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9773 - accuracy: 0.1443
# Epoch 22/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9770 - accuracy: 0.1454
# Epoch 23/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9768 - accuracy: 0.1457
# Epoch 24/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9766 - accuracy: 0.1455
# Epoch 25/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9765 - accuracy: 0.1450
# Epoch 26/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9763 - accuracy: 0.1454
# Epoch 27/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9762 - accuracy: 0.1445
# Epoch 28/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9760 - accuracy: 0.1451
# Epoch 29/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9759 - accuracy: 0.1458
# Epoch 30/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9758 - accuracy: 0.1448
# Epoch 31/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9757 - accuracy: 0.1445
# Epoch 32/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9756 - accuracy: 0.1450
# Epoch 33/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9755 - accuracy: 0.1448
# Epoch 34/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9754 - accuracy: 0.1454
# Epoch 35/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9753 - accuracy: 0.1453
# Epoch 36/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9752 - accuracy: 0.1448
# Epoch 37/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9751 - accuracy: 0.1449
# Epoch 38/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9751 - accuracy: 0.1455
# Epoch 39/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9750 - accuracy: 0.1453
# Epoch 40/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9749 - accuracy: 0.1448
# Epoch 41/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9748 - accuracy: 0.1446
# Epoch 42/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9748 - accuracy: 0.1457
# Epoch 43/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9747 - accuracy: 0.1446
# Epoch 44/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9747 - accuracy: 0.1448
# Epoch 45/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9746 - accuracy: 0.1456
# Epoch 46/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.9746 - accuracy: 0.1457
# Epoch 47/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.9745 - accuracy: 0.1456
# Epoch 48/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9745 - accuracy: 0.1452
# Epoch 49/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.9745 - accuracy: 0.1445
# Epoch 50/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9744 - accuracy: 0.1455
# Epoch 51/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9744 - accuracy: 0.1441
# Epoch 52/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9743 - accuracy: 0.1455
# Epoch 53/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9743 - accuracy: 0.1460
# Epoch 54/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9743 - accuracy: 0.1444
# Epoch 55/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9742 - accuracy: 0.1445
# Epoch 56/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9742 - accuracy: 0.1451
# Epoch 57/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9742 - accuracy: 0.1446
# Epoch 58/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9741 - accuracy: 0.1454
# Epoch 59/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9741 - accuracy: 0.1449
# Epoch 60/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9741 - accuracy: 0.1454
# Epoch 61/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9740 - accuracy: 0.1447
# Epoch 62/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9740 - accuracy: 0.1451
# Epoch 63/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9740 - accuracy: 0.1455
# Epoch 64/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9740 - accuracy: 0.1456
# Epoch 65/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9739 - accuracy: 0.1451
# Epoch 66/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9739 - accuracy: 0.1453
# Epoch 67/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9739 - accuracy: 0.1449
# Epoch 68/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9739 - accuracy: 0.1450
# Epoch 69/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9738 - accuracy: 0.1454
# Epoch 70/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9738 - accuracy: 0.1454
# Epoch 71/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9738 - accuracy: 0.1449
# Epoch 72/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9738 - accuracy: 0.1455
# Epoch 73/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9738 - accuracy: 0.1453
# Epoch 74/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9738 - accuracy: 0.1446
# Epoch 75/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9737 - accuracy: 0.1463
# Epoch 76/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9737 - accuracy: 0.1453
# Epoch 77/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9737 - accuracy: 0.1454
# Epoch 78/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9737 - accuracy: 0.1452
# Epoch 79/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9737 - accuracy: 0.1447
# Epoch 80/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9737 - accuracy: 0.1455
# Epoch 81/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9736 - accuracy: 0.1442
# Epoch 82/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9736 - accuracy: 0.1450
# Epoch 83/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9736 - accuracy: 0.1455
# Epoch 84/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9736 - accuracy: 0.1447
# Epoch 85/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9736 - accuracy: 0.1447
# Epoch 86/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.9736 - accuracy: 0.1460
# Epoch 87/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9736 - accuracy: 0.1460
# Epoch 88/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1443
# Epoch 89/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1456
# Epoch 90/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1455
# Epoch 91/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1456
# Epoch 92/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1453
# Epoch 93/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1450
# Epoch 94/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1457
# Epoch 95/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9735 - accuracy: 0.1450
# Epoch 96/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1451
# Epoch 97/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1453
# Epoch 98/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1446
# Epoch 99/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1448
# Epoch 100/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1456
# Epoch 101/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1454
# Epoch 102/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1453
# Epoch 103/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1450
# Epoch 104/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1461
# Epoch 105/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1455
# Epoch 106/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9734 - accuracy: 0.1455
# Epoch 107/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1458
# Epoch 108/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1454
# Epoch 109/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1453
# Epoch 110/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1448
# Epoch 111/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1450
# Epoch 112/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1450
# Epoch 113/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1448
# Epoch 114/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1454
# Epoch 115/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1453
# Epoch 116/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1459
# Epoch 117/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1444
# Epoch 118/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9733 - accuracy: 0.1450
# Epoch 119/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1450
# Epoch 120/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1442
# Epoch 121/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1450
# Epoch 122/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1451
# Epoch 123/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1460
# Epoch 124/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1448
# Epoch 125/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1451
# Epoch 126/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1453
# Epoch 127/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1457
# Epoch 128/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1454
# Epoch 129/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1450
# Epoch 130/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1453
# Epoch 131/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1446
# Epoch 132/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1456
# Epoch 133/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1444
# Epoch 134/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1451
# Epoch 135/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9732 - accuracy: 0.1441
# Epoch 136/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1455
# Epoch 137/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1451
# Epoch 138/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1445
# Epoch 139/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1445
# Epoch 140/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1457
# Epoch 141/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1456
# Epoch 142/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.9731 - accuracy: 0.1455
# Epoch 143/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1450
# Epoch 144/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1451
# Epoch 145/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1444
# Epoch 146/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1459
# Epoch 147/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1455
# Epoch 148/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1451
# Epoch 149/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1450
# Epoch 150/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9731 - accuracy: 0.1456
# 2813/2813 [==============================] - 2s 771us/step - loss: 2.9730 - accuracy: 0.1462
# Train: 0.146, Test: 0.143
# (90000, 3) (10000, 3) (90000,) (10000,)
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4653 - accuracy: 0.0340
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4402 - accuracy: 0.0601
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.0048 - accuracy: 0.0699
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.8350 - accuracy: 0.1066
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.6585 - accuracy: 0.1403
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.5098 - accuracy: 0.1598
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.3736 - accuracy: 0.1722
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.2401 - accuracy: 0.1801
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.1246 - accuracy: 0.2060
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.0477 - accuracy: 0.2194
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.9931 - accuracy: 0.2286
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.9528 - accuracy: 0.2231
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.8952 - accuracy: 0.2459
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.8141 - accuracy: 0.2764
# 2813/2813 [==============================] - 2s 760us/step - loss: 1.7453 - accuracy: 0.3238
# Epoch 1/15
# ...
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 114/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 115/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0310
# Epoch 116/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 117/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 118/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 119/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0301
# Epoch 120/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0297
# Epoch 121/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 122/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 123/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 124/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 125/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 126/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 127/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 128/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0312
# Epoch 129/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0304
# Epoch 130/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 131/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 132/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 133/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 134/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0307
# Epoch 135/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0305
# Epoch 136/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0309
# Epoch 137/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0302
# Epoch 138/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0311
# Epoch 139/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0300
# Epoch 140/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 141/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 142/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 143/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0307
# Epoch 144/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0312
# Epoch 145/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0305
# Epoch 146/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# Epoch 147/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0314
# Epoch 148/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 149/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 150/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0306
# 2813/2813 [==============================] - 2s 773us/step - loss: 3.4657 - accuracy: 0.0315
# Train: 0.032, Test: 0.029
# (90000, 3) (10000, 3) (90000,) (10000,)
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4656 - accuracy: 0.0297
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4587 - accuracy: 0.0480
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.1005 - accuracy: 0.0641
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.8329 - accuracy: 0.1088
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.7618 - accuracy: 0.1138
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.7429 - accuracy: 0.1162
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.5454 - accuracy: 0.1273
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.4280 - accuracy: 0.1465
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.3284 - accuracy: 0.1628
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.2704 - accuracy: 0.1625
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.2403 - accuracy: 0.1702
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.1809 - accuracy: 0.1886
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.1475 - accuracy: 0.1932
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.0872 - accuracy: 0.2089
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.0706 - accuracy: 0.2151
# 2813/2813 [==============================] - 3s 886us/step - loss: 2.3952 - accuracy: 0.1044
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0313
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0316
# Epoch 3/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0318
# Epoch 4/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0298
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0322
# Epoch 6/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0321
# Epoch 7/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0303
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0308
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0304
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0320
# Epoch 11/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4658 - accuracy: 0.0320
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0321
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0323
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0312
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0311
# 2813/2813 [==============================] - 2s 780us/step - loss: 3.4657 - accuracy: 0.0317
# Epoch 1/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 3.4592 - accuracy: 0.0435
# Epoch 2/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.9342 - accuracy: 0.0715
# Epoch 3/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.4500 - accuracy: 0.1494
# Epoch 4/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 2.2362 - accuracy: 0.1895
# Epoch 5/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.0673 - accuracy: 0.2244
# Epoch 6/15
# 2813/2813 [==============================] - 4s 1ms/step - loss: 1.9781 - accuracy: 0.2510
# Epoch 7/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.9185 - accuracy: 0.2668
# Epoch 8/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.8340 - accuracy: 0.2926
# Epoch 9/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 2.0555 - accuracy: 0.2731
# Epoch 10/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.7897 - accuracy: 0.3089
# Epoch 11/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.6894 - accuracy: 0.3408
# Epoch 12/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.6368 - accuracy: 0.3571
# Epoch 13/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.5735 - accuracy: 0.3843
# Epoch 14/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.6141 - accuracy: 0.3935
# Epoch 15/15
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.5107 - accuracy: 0.4373
# 2813/2813 [==============================] - 2s 738us/step - loss: 1.2588 - accuracy: 0.4693
# Epoch 1/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3852 - accuracy: 0.4811
# Epoch 2/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3527 - accuracy: 0.4955
# Epoch 3/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3301 - accuracy: 0.5078
# Epoch 4/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3074 - accuracy: 0.5215
# Epoch 5/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.4705 - accuracy: 0.5053
# Epoch 6/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 1.3553 - accuracy: 0.4966
# Epoch 7/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 1.2877 - accuracy: 0.5273
# Epoch 8/150
# 2813/2813 [==============================] - 4s 1ms/step - loss: 1.6932 - accuracy: 0.4777
# Epoch 9/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4890 - accuracy: 0.0312
# Epoch 10/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4718 - accuracy: 0.0301
# Epoch 11/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4672 - accuracy: 0.0303
# Epoch 12/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4661 - accuracy: 0.0300
# Epoch 13/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0303
# Epoch 14/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0312
# Epoch 15/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0300
# Epoch 16/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0307
# Epoch 17/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4658 - accuracy: 0.0307
# Epoch 18/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0317
# Epoch 19/150
# 2813/2813 [==============================] - 3s 1ms/step - loss: 3.4659 - accuracy: 0.0302
# Epoch 20/150
# 1862/2813 [==================>...........] - ETA: 1s - loss: 3.4659 - accuracy: 0.0297
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-e8563b7b85e1> in <module>
#      54         _, train_acc = model.evaluate(x_train, y_traininput, verbose=1)
#      55
# ---> 56     history = model.fit(x_train, y_traininput, epochs=150, verbose = 1)
#      57
#      58     _, train_acc = model.evaluate(x_train, y_traininput, verbose=1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _build_call_outputs(self, result)
#    2172         outputs_list[i] = result[j]
#    2173         j += 1
# -> 2174     ret = nest.pack_sequence_as(self._func_graph.structured_outputs,
#    2175                                 outputs_list, expand_composites=True)
#    2176     return ret
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in pack_sequence_as(structure, flat_sequence, expand_composites)
#     577     TypeError: `structure` is or contains a dict with non-sortable keys.
#     578   """
# --> 579   return _pack_sequence_as(structure, flat_sequence, expand_composites)
#     580
#     581
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in _pack_sequence_as(structure, flat_sequence, expand_composites, sequence_fn)
#     529
#     530   try:
# --> 531     final_index, packed = _packed_nest_with_indices(structure, flat_sequence,
#     532                                                     0, is_seq, sequence_fn)
#     533     if final_index < len(flat_sequence):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in _packed_nest_with_indices(structure, flat, index, is_seq, sequence_fn)
#     491   packed = []
#     492   sequence_fn = sequence_fn or _sequence_like
# --> 493   for s in _yield_value(structure):
#     494     if is_seq(s):
#     495       new_index, child = _packed_nest_with_indices(s, flat, index, is_seq,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in _yield_value(iterable)
#     197
#     198 def _yield_value(iterable):
# --> 199   for _, v in _yield_sorted_items(iterable):
#     200     yield v
#     201
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/util/nest.py in _yield_sorted_items(iterable)
#     217   """
#     218   # Ordered to check common structure types (list, tuple, dict) first.
# --> 219   if isinstance(iterable, list):
#     220     for item in enumerate(iterable):
#     221       yield item
#
# KeyboardInterrupt:

# %%
_, train_acc = model.evaluate(x_train, y_train, verbose=0)
_, test_acc = model.evaluate(x_test, y_test, verbose=0)
print('Train: %.3f, Test: %.3f' % (train_acc, test_acc))
# plot loss during training
pyplot.subplot(211)
pyplot.title('Loss')
pyplot.plot(history.history['loss'], label='train')
pyplot.legend()
# plot accuracy during training
pyplot.subplot(212)
pyplot.title('Accuracy')
pyplot.plot(history.history['accuracy'], label='train')
pyplot.legend()
pyplot.show()

# %%
with open('Countercorrectionmodel3669.pkl', 'wb') as f:
    pickle.dump({'weights': model.get_weights(), 'history': history.history}, f)

# %%
# load the weights and history from the file and evaluate the model
with open('Countercountermodel.pkl', 'rb') as f:
    data = pickle.load(f)
model.set_weights(data['weights'])

# %%
predictions = model.predict(np.asarray(x).astype('float32'))
y_pred_classes = np.argmax(predictions, axis=1)
    
    # compute class-wise accuracy and confusion matrix
class_correct = [0] * 32
class_total = [0] * 32
class_true = [0] * 32
class_false = [[0] * 32 for _ in range(32)]

for i in range(len(y)):
    true_class = y[i]
    pred_class = y_pred_classes[i]

    if true_class == pred_class:
        class_correct[true_class] += 1
        class_true[true_class] += 1
    else:
        class_false[true_class][pred_class] += 1

    class_total[true_class] += 1

class_accuracy = [class_correct[i] / (class_total[i] + 1) for i in range(32)]
    
for class_id in range(32):
            print(f"Class {class_id}:")
            print(f"  Total: {class_total[class_id]}")
            print(f"  Correct: {class_correct[class_id]}")
            print(f"  True {class_id}: {class_true[class_id]}")
            print(f"  False: {class_false[class_id]}")
            print(f"  Accuracy: {class_accuracy[class_id]}")
