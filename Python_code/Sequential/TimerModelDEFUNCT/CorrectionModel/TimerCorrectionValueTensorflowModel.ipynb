# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import pickle
from matplotlib import pyplot
from keras.optimizers import SGD
np.set_printoptions(threshold=np.sys.maxsize)
# Out:
# /Users/omristeinberg-tatman/opt/anaconda3/lib/python3.8/site-packages/scipy/__init__.py:138: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4)
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion} is required for this version of "

# %%
#define the data
FullData = pd.read_csv("timer_Correction_Data_Value.csv")

x, y = FullData.values[:, :-1], FullData.values[:, -1]
x_train =  x[0:15000]
x_test =  x[15001:26039]
y_train = y[0:15000]
y_test = y[15001:26039]
print(x_train.shape, x_test.shape, y_train.shape, y_test.shape)
n_features = x_train.shape[1]
# Out:
# (15000, 3) (11038, 3) (15000,) (11038,)

# %%
y_traininput = tf.keras.utils.to_categorical(y_train)
y_testinput = tf.keras.utils.to_categorical(y_test)

# %%
# define the model
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(100, input_shape=(n_features,), activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(80, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(30, activation= "relu"))
model.add(tf.keras.layers.Dense(10, activation= "relu"))
model.add(tf.keras.layers.Dense(10, activation= "relu"))
model.add(tf.keras.layers.Dense(10, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(5, activation= "relu"))
model.add(tf.keras.layers.Dense(32, activation='softmax'))

opt = SGD(lr=0.01)#, momentum=0.9)

model.compile(optimizer=opt, loss="categorical_crossentropy", metrics=['accuracy'])

# %%
history = model.fit(x_train, y_traininput, epochs=10000, verbose=1, batch_size = 10000)#validation_data=(x_test, y_test), epochs=100, verbose=1)
# Out:
# Epoch 1/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 2/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 3/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 4/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 5/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 6/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 7/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 8/10000
# 2/2 [==============================] - 0s 18ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 9/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 10/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 11/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 12/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 13/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 14/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 15/10000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 16/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 17/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 18/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 19/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 20/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 21/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 22/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 23/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 24/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 25/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 26/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 27/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 28/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 29/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 30/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 31/10000
# 2/2 [==============================] - 0s 35ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 32/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 33/10000
# 2/2 [==============================] - 0s 17ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 34/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 35/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 36/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 37/10000
# 2/2 [==============================] - 0s 35ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 38/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 39/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 40/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 41/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 42/10000
# 2/2 [==============================] - 0s 19ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 43/10000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 44/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 45/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 46/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 47/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 48/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 49/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 50/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 51/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 52/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 53/10000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 54/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 55/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 56/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 57/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 58/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 59/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 60/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 61/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 62/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 63/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 64/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 65/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 66/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 67/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 68/10000
# 2/2 [==============================] - 0s 19ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 69/10000
# 2/2 [==============================] - 0s 19ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 70/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 71/10000
# 2/2 [==============================] - 0s 17ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 72/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 73/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 74/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 75/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 76/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 77/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 78/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 79/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 80/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 81/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 82/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 83/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 84/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 85/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 86/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 87/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 88/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 89/10000
# 2/2 [==============================] - 0s 32ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 90/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 91/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 92/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 93/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 94/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 95/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 96/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 97/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 98/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 99/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 100/10000
# 2/2 [==============================] - 0s 18ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 101/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 102/10000
# 2/2 [==============================] - 0s 19ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 103/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 104/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 105/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 106/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 107/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 108/10000
# 2/2 [==============================] - 0s 28ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 109/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 110/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 111/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 112/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0319
# Epoch 113/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 114/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 115/10000
# 2/2 [==============================] - 0s 16ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 116/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 117/10000
# 2/2 [==============================] - 0s 18ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 118/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 119/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 120/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 121/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 122/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 123/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 124/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 125/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 126/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 127/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 128/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 129/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 130/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 131/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 132/10000
# 2/2 [==============================] - 0s 36ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 133/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 134/10000
# 2/2 [==============================] - 0s 17ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 135/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 136/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 137/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 138/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 139/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 140/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 141/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 142/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 143/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 144/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 145/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 146/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 147/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 148/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 149/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 150/10000
# 2/2 [==============================] - 0s 23ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 151/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 152/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 153/10000
# 2/2 [==============================] - 0s 22ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 154/10000
# 2/2 [==============================] - 0s 31ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 155/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 156/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 157/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 158/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 159/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 160/10000
# 2/2 [==============================] - 0s 24ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 161/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 162/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 163/10000
# 2/2 [==============================] - 0s 29ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 164/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 165/10000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 166/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 167/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 168/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 169/10000
# 2/2 [==============================] - 0s 27ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 170/10000
# 2/2 [==============================] - 0s 26ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 171/10000
# 2/2 [==============================] - 0s 30ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 172/10000
# 2/2 [==============================] - 0s 25ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 173/10000
# 2/2 [==============================] - 0s 21ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 174/10000
# 2/2 [==============================] - 0s 20ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 175/10000
# 2/2 [==============================] - 0s 33ms/step - loss: 3.4657 - accuracy: 0.0311
# Epoch 176/10000
# 2/2 [==============================] - 0s 37ms/step - loss: 3.4657 - accuracy: 0.0313
# Epoch 177/10000
# 1/2 [==============>...............] - ETA: 0s - loss: 3.4657 - accuracy: 0.0308
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-a3b175e7509b> in <module>
# ----> 1 history = model.fit(x_train, y_traininput, epochs=10000, verbose=1, batch_size = 10000)#validation_data=(x_test, y_test), epochs=100, verbose=1)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
