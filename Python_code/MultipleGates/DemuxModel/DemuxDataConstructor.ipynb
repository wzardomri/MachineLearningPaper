# %%
import pandas as pd
import numpy as np
import random

Demux_Verification_Data = pd.DataFrame(columns = ["clock", "D0", "S0", "S1", "S2", "out1", "out2", "out3", "out4", "out5", "out6", "out7", "out8", "CORRECT"])
Demux_Correction_Data = pd.DataFrame(columns = ["clock", "D0", "S0", "S1", "S2", "out1", "out2", "out3", "out4", "out5", "out6", "out7", "out8"])
readin = pd.read_csv("demux_csv.txt")

# %%
Demux_Correction_Data["clock"] = readin["clock"]
Demux_Correction_Data["D0"] = readin["D0"]
Demux_Correction_Data["S0"] = readin["S0"]
Demux_Correction_Data["S1"] = readin["S1"]
Demux_Correction_Data["S2"] = readin["S2"]
Demux_Correction_Data["out1"] = readin["out1"]
Demux_Correction_Data["out2"] = readin["out2"]
Demux_Correction_Data["out3"] = readin["out3"]
Demux_Correction_Data["out4"] = readin["out4"]
Demux_Correction_Data["out5"] = readin["out5"]
Demux_Correction_Data["out6"] = readin["out6"]
Demux_Correction_Data["out7"] = readin["out7"]
Demux_Correction_Data["out8"] = readin["out8"]

Demux_Verification_Data["clock"] = Demux_Correction_Data["clock"]
Demux_Verification_Data["D0"] = Demux_Correction_Data["D0"]
Demux_Verification_Data["S0"] = Demux_Correction_Data["S0"]
Demux_Verification_Data["S1"] = Demux_Correction_Data["S1"]
Demux_Verification_Data["S2"] = Demux_Correction_Data["S2"]
Demux_Verification_Data["out1"] = Demux_Correction_Data["out1"]
Demux_Verification_Data["out2"] = Demux_Correction_Data["out2"]
Demux_Verification_Data["out3"] = Demux_Correction_Data["out3"]
Demux_Verification_Data["out4"] = Demux_Correction_Data["out4"]
Demux_Verification_Data["out5"] = Demux_Correction_Data["out5"]
Demux_Verification_Data["out6"] = Demux_Correction_Data["out6"]
Demux_Verification_Data["out7"] = Demux_Correction_Data["out7"]
Demux_Verification_Data["out8"] = Demux_Correction_Data["out8"]
Demux_Verification_Data["CORRECT"] = Demux_Correction_Data["out8"]




Demux_Correction_Data.to_csv("Demux_Correction_Data.csv")

# %%
for item in list(range(0,len(Demux_Verification_Data))):
    check = random.randint(0,9);
    
    if(check%2 == 1):
        Demux_Verification_Data["CORRECT"][item] = 0
        newcheck = random.randint(0,9)
        #newcheck = [0,1,9,1,0,9,1,1,9,0][newcheck] #[0,0,9,9,0,9,9,0,9,0]
        if(sum(Demux_Verification_Data.values[item,-9:-1]) == 0):
            Demux_Verification_Data["out1"][item] = 0
            Demux_Verification_Data["out2"][item] = 0
            Demux_Verification_Data["out3"][item] = 0
            Demux_Verification_Data["out4"][item] = 0
            Demux_Verification_Data["out5"][item] = 0
            Demux_Verification_Data["out6"][item] = 0
            Demux_Verification_Data["out7"][item] = 0
            Demux_Verification_Data["out8"][item] = 1
        elif(newcheck == 0):
            Demux_Verification_Data["out1"][item] = 0
            Demux_Verification_Data["out2"][item] = 0
            Demux_Verification_Data["out3"][item] = 0
            Demux_Verification_Data["out4"][item] = 0
            Demux_Verification_Data["out5"][item] = 0
            Demux_Verification_Data["out6"][item] = 0
            Demux_Verification_Data["out7"][item] = 0
            Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 1):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 0):
                Demux_Verification_Data["out1"][item] = 1
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
            else:
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 1
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 2):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 1):
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 1
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
            else:
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 1
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 3):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 2):
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 1
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
            else:
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 1
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 4):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 3):
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 1
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
            else:
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 1
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 5):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 4):
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 1
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
            else:
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 1
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 6):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 5):
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 1
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
            else:
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 1
                Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 7):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 6):
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 1
                Demux_Verification_Data["out8"][item] = 0
            else:
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 1
        elif(newcheck == 8):
            if((list(Demux_Verification_Data.values[item,-9:-1]).index(1)) != 7):
                Demux_Verification_Data["out1"][item] = 0
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 1
            else:
                Demux_Verification_Data["out1"][item] = 1
                Demux_Verification_Data["out2"][item] = 0
                Demux_Verification_Data["out3"][item] = 0
                Demux_Verification_Data["out4"][item] = 0
                Demux_Verification_Data["out5"][item] = 0
                Demux_Verification_Data["out6"][item] = 0
                Demux_Verification_Data["out7"][item] = 0
                Demux_Verification_Data["out8"][item] = 0
        elif(newcheck == 9):
            Demux_Verification_Data["out1"][item] = 1
            Demux_Verification_Data["out2"][item] = random.randint(0,1)
            Demux_Verification_Data["out3"][item] = random.randint(0,1)
            Demux_Verification_Data["out4"][item] = random.randint(0,1)
            Demux_Verification_Data["out5"][item] = random.randint(0,1)
            Demux_Verification_Data["out6"][item] = random.randint(0,1)
            Demux_Verification_Data["out7"][item] = 1
            Demux_Verification_Data["out8"][item] = random.randint(0,1)
        else:
            print("uhoh1")
    elif(check%2 == 0):
        Demux_Verification_Data["CORRECT"][item] = 1;
    else:
        print("uhoh2")

# %%
Demux_Verification_Data.to_csv("Demux_Verification_Data.csv")
